# %% [markdown]
# # Convolutions

# %% [markdown]
# Showing off the use of convolution by example of the MNIST data set.

# %% [markdown]
# ## Imports

# %%
# -*- coding: utf-8 -*-
from __future__ import division
from copy import deepcopy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import theano
import theano.tensor as T

# %%
from netz.layers import InputLayer, DenseLayer, OutputLayer, Conv2DLayer, MaxPool2DLayer, DropoutLayer
from netz.neuralnet import NeuralNet
from netz.costfunctions import mse, crossentropy
from netz.nonlinearities import rectify
from netz.updaters import Momentum, Nesterov, SGD
from netz.visualize import plot_loss, plot_conv_weights, plot_conv_activity, plot_occlusion

# %%
import netz.utils
reload(netz.utils)
import netz.visualize
reload(netz.visualize)
# Out:
# <module 'netz.visualize' from 'netz\visualize.pyc'>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Data

# %% [markdown]
# Make sure you have the MNIST data set ready. You can get it here: http://www.kaggle.com/c/digit-recognizer/data.

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('../data/mnist.csv')

# %%
y = df.values[:, 0]
X = df.values[:, 1:] / 255

# %%
X = X.astype(theano.config.floatX)

# %%
X = (X - X.mean()) / X.std()

# %%
X2D = X.reshape(-1, 1, 28, 28)

# %% [markdown]
# ### Plot data

# %%
figs, axes = plt.subplots(4, 4, figsize=(6, 6))
for i in range(4):
    for j in range(4):
        axes[i, j].imshow(-X2D[i + 4 * j][0], cmap='gray', interpolation='nearest')
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_title("Label: {}".format(y[i + 4 * j]))
        axes[i, j].axis('off')

# %% [markdown]
# ## Neural net

# %% [markdown]
# ### Including pooling layer and using rectified linear units instead of sigmoid

# %%
layers1 = [InputLayer(),
           Conv2DLayer(16, (7, 7), nonlinearity=rectify, lambda2=0.01),
           MaxPool2DLayer(ds=(2, 2)),
           Conv2DLayer(32, (5, 5), nonlinearity=rectify, lambda2=0.01),
           MaxPool2DLayer(),
           Conv2DLayer(32, (3, 3), nonlinearity=rectify, lambda2=0.01),
           DropoutLayer(p=0.5),
           DenseLayer(100, nonlinearity=rectify),
           DenseLayer(50, nonlinearity=rectify),
           OutputLayer()]

# %%
net1 = NeuralNet(layers1, cost_function=crossentropy, updater=Nesterov(), verbose=1, eval_size=0.1)

# %%
net1.fit(X2D, y, max_iter=10)
# Out:
# # Neural Network with 41340 learnable parameters
#
#
# ## Layer information
# | name       | size     |   total |   cap. Y [%] |   cap. X [%] |   cov. Y [%] |   cov. X [%] |
# |:-----------|:---------|--------:|-------------:|-------------:|-------------:|-------------:|
# | input0     | 1x28x28  |     784 |       100.00 |       100.00 |       100.00 |       100.00 |
# | conv2d0    | 16x22x22 |    7744 |       100.00 |       100.00 |        25.00 |        25.00 |
# | maxpool2d0 | 16x11x11 |    1936 |       100.00 |       100.00 |        25.00 |        25.00 |
# | conv2d1    | 32x7x7   |    1568 |        66.67 |        66.67 |        53.57 |        53.57 |
# | maxpool2d1 | 32x4x4   |     512 |        66.67 |        66.67 |        53.57 |        53.57 |
# | conv2d2    | 32x2x2   |     128 |        52.17 |        52.17 |        82.14 |        82.14 |
# | dropout0   | 32x2x2   |     128 |       100.00 |       100.00 |       100.00 |       100.00 |
# | dense0     | 100      |     100 |       100.00 |       100.00 |       100.00 |       100.00 |
# | dense1     | 50       |      50 |       100.00 |       100.00 |       100.00 |       100.00 |
# | output0    | 10       |      10 |       100.00 |       100.00 |       100.00 |       100.00 |
#
# Explanation
#     X, Y:    image dimensions
#     cap.:    learning capacity
#     cov.:    coverage of image
#     magenta: capacity too low (<1/6)
#     cyan:    image coverage too high (>100%)
#     red:     capacity too low and coverage too high
#
# ## Training Information
#  Epoch | Train loss | Valid loss | Train/Val | Valid acc | Dur
# -------|------------|------------|-----------|-----------|------
#      0 |   0.997718 |   0.387089 |    2.577  |  0.9446   | 218.4s
#      1 |   0.393494 |   0.255878 |    1.538  |  0.9698   | 212.2s
#      2 |   0.274768 |   0.208216 |    1.320  |  0.9727   | 197.3s
#      3 |   0.221597 |   0.170387 |    1.301  |  0.9793   | 199.5s
#      4 |   0.187146 |   0.149876 |    1.249  |  0.9815   | 208.7s
#      5 |   0.165744 |   0.131783 |    1.258  |  0.9836   | 190.3s
#      6 |   0.156563 |   0.126678 |    1.236  |  0.9819   | 194.5s
#      7 |   0.143323 |   0.121302 |    1.182  |  0.9857   | 199.2s
#      8 |   0.136749 |   0.129728 |    1.054  |  0.9815   | 189.8s
#      9 |   0.131134 |   0.109283 |    1.200  |  0.9888   | 201.0s
# NeuralNet(connection_pattern=None,
#      cost_function=<function crossentropy at 0x0000000016A43EB8>,
#      encoder=OneHotEncoder(categorical_features='all', dtype=dtype('int64'),
#        n_values='auto', sparse=False),
#      eval_size=0.1,
#      iterator=<nolearn.lasagne.BatchIterator object at 0x0000000016D47BE0>,
#      lambda2=None,
#      layers=[input0, conv2d0, maxpool2d0, conv2d1, maxpool2d1, conv2d2, dropout0, dense0, dense1, output0],
#      recurrent=False, regression=False,
#      updater=<netz.updaters.Nesterov object at 0x000000002BAA56D8>,
#      verbose=1)

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Show progress of train and valid loss

# %%
plot_loss(net1)

# %% [markdown]
# #### Show the learned weights of the first convolution layer

# %%
plot_conv_weights(net1.layers[1], figsize(4, 4))

# %% [markdown]
# #### Show the activities generated by different images in different layers

# %%
plot_conv_activity(net1.layers[1], X2D[1:2])

# %%
plot_conv_activity(net1.layers[1], X2D[6:7])

# %%
plot_conv_activity(net1.layers[3], X2D[7:8])

# %%
plot_conv_activity(net1.layers[5], X2D[7:8])

# %%
plot_conv_activity(net1.layers[5], X2D[9:10])

# %%
plot_conv_activity(net1.layers[5], X2D[8: 9])

# %% [markdown]
# #### Show which part of the image is important in predicting the correct class

# %% [markdown]
# This is achieved by occluding parts of the image and looking at how prediction quality deteriorates.

# %%
plot_occlusion(net1, X2D[9:12], y[9:12])
