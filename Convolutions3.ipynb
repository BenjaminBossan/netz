# %% [markdown]
# # Convolutions

# %% [markdown]
# Showing off the use of convolution by example of the MNIST data set.

# %% [markdown]
# ## Imports

# %%
# -*- coding: utf-8 -*-
from __future__ import division
from copy import deepcopy

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import theano
import theano.tensor as T

# %%
from netz.layers import InputLayer, DenseLayer, OutputLayer, Conv2DLayer, MaxPool2DLayer, DropoutLayer
from netz.neuralnet import NeuralNet
from netz.costfunctions import mse, crossentropy
from netz.nonlinearities import rectify
from netz.updaters import Momentum, Nesterov, SGD
from netz.visualize import plot_loss, plot_conv_weights, plot_conv_activity, plot_occlusion

# %%
import netz.utils
reload(netz.utils)
import netz.visualize
reload(netz.visualize)
# Out:
# <module 'netz.visualize' from 'netz\visualize.pyc'>

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Data

# %% [markdown]
# Make sure you have the MNIST data set ready. You can get it here: http://www.kaggle.com/c/digit-recognizer/data.

# %% [markdown]
# ### Load data

# %%
df = pd.read_csv('../data/mnist.csv')

# %%
y = df.values[:, 0]
X = df.values[:, 1:] / 255

# %%
X = X.astype(theano.config.floatX)

# %%
X = (X - X.mean()) / X.std()

# %%
X2D = X.reshape(-1, 1, 28, 28)

# %% [markdown]
# ### Plot data

# %%
figs, axes = plt.subplots(4, 4, figsize=(6, 6))
for i in range(4):
    for j in range(4):
        axes[i, j].imshow(-X2D[i + 4 * j][0], cmap='gray', interpolation='nearest')
        axes[i, j].set_xticks([])
        axes[i, j].set_yticks([])
        axes[i, j].set_title("Label: {}".format(y[i + 4 * j]))
        axes[i, j].axis('off')

# %% [markdown]
# ## Neural net

# %% [markdown]
# ### Including pooling layer and using rectified linear units instead of sigmoid

# %%
layers1 = [InputLayer(),
           Conv2DLayer(16, (7, 7), nonlinearity=rectify, lambda2=0.01),
           MaxPool2DLayer(ds=(2, 2)),
           Conv2DLayer(32, (5, 5), nonlinearity=rectify, lambda2=0.01),
           MaxPool2DLayer(),
           Conv2DLayer(32, (3, 3), nonlinearity=rectify, lambda2=0.01),
           DropoutLayer(p=0.5),
           DenseLayer(100, nonlinearity=rectify),
           DenseLayer(50, nonlinearity=rectify),
           OutputLayer()]

# %%
net1 = NeuralNet(layers1, cost_function=crossentropy, updater=Nesterov(), verbose=1, eval_size=0.1)

# %%
net1.fit(X2D, y, max_iter=10)
# Out:
# # ~=* Neural Network with 41340 learnable parameters *=~
#
#
# ## Layer information
#   # | name         | output shape       |        total
# ----|--------------|--------------------|--------------
#   0 | input0       | (None, 1, 28, 28)  |          784
#   1 | conv2d0      | (None, 16, 22, 22) |         7744
#   2 | maxpool2d0   | (None, 16, 11, 11) |         1936
#   3 | conv2d1      | (None, 32, 7, 7)   |         1568
#   4 | maxpool2d1   | (None, 32, 4, 4)   |          512
#   5 | conv2d2      | (None, 32, 2, 2)   |          128
#   6 | dropout0     | (None, 32, 2, 2)   |          128
#   7 | dense0       | (None, 100)        |          100
#   8 | dense1       | (None, 50)         |           50
#   9 | output0      | (None, 10)         |           10
#
#
# ## Training Information
#  Epoch | Train loss | Valid loss | Train/Val | Valid acc | Dur
# -------|------------|------------|-----------|-----------|------
#      0 |   0.988603 |   0.365306 |    2.706  |  0.9565   | 181.6s
#      1 |   0.380037 |   0.243812 |    1.559  |  0.9760   | 176.1s
#      2 |   0.270944 |   0.190204 |    1.424  |  0.9805   | 162.8s
#      3 |   0.218988 |   0.169953 |    1.289  |  0.9791   | 173.2s
#      4 |   0.185820 |   0.138472 |    1.342  |  0.9836   | 165.0s
#      5 |   0.166264 |   0.132030 |    1.259  |  0.9848   | 171.1s
#      6 |   0.150252 |   0.121150 |    1.240  |  0.9862   | 172.6s
#      7 |   0.141495 |   0.116183 |    1.218  |  0.9850   | 165.3s
#      8 |   0.138818 |   0.125424 |    1.107  |  0.9822   | 185.1s
#      9 |   0.133520 |   0.115559 |    1.155  |  0.9855   | 178.1s
# NeuralNet(cost_function=<function crossentropy at 0x0000000016950048>,
#      eval_size=0.1,
#      iterator=<nolearn.lasagne.BatchIterator object at 0x0000000016C348D0>,
#      lambda2=None,
#      layers=[<netz.layers.InputLayer object at 0x000000002DFAE748>, <netz.layers.Conv2DLayer object at 0x000000002DFAE780>, <netz.layers.MaxPool2DLayer object at 0x0000000016C79668>, <netz.layers.Conv2DLayer object at 0x000000002DFAE2E8>, <netz.layers.MaxPool2DLayer object at 0x000000002DFAE358>, <netz.l...rs.DenseLayer object at 0x000000002DFAE0B8>, <netz.layers.OutputLayer object at 0x000000002DFAE0F0>],
#      updater=<netz.updaters.Nesterov object at 0x0000000016C79940>,
#      verbose=1)

# %% [markdown]
# ### Visualizations

# %% [markdown]
# #### Show progress of train and valid loss

# %%
plot_loss(net1)

# %% [markdown]
# #### Show the learned weights of the first convolution layer

# %%
plot_conv_weights(net1.layers[1], figsize(4, 4))

# %% [markdown]
# #### Show the activities generated by different images in different layers

# %%
plot_conv_activity(net1.layers[1], X2D[1:2])

# %%
plot_conv_activity(net1.layers[1], X2D[6:7])

# %%
plot_conv_activity(net1.layers[3], X2D[7:8])

# %%
plot_conv_activity(net1.layers[5], X2D[7:8])

# %%
plot_conv_activity(net1.layers[5], X2D[9:10])

# %%
plot_conv_activity(net1.layers[5], X2D[8: 9])

# %% [markdown]
# #### Show which part of the image is important in predicting the correct class

# %% [markdown]
# This is achieved by occluding parts of the image and looking at how prediction quality deteriorates.

# %%
plot_occlusion(net1, X2D[9:12], y[9:12])
